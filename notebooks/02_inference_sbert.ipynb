# %% [markdown]
# # Inference Notebook: SBERT
#
# This notebook loads a trained baseline and returns the project target output shape.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

PROJECT_ROOT
# Out:
# PosixPath('/Users/punpunpmbp/Documents/Documents/THU_Project/DL/semantic-resume_job-matching-system')

# %% [markdown]
# ## Load Model
#
# Run the training notebook first so `artifacts/sbert_logreg` exists.

# %%
from semantic_resume_matcher.embeddings.inference import SbertLogRegMatcher

artifact_dir = PROJECT_ROOT / "artifacts" / "sbert_logreg"
matcher = SbertLogRegMatcher.from_artifact_dir(artifact_dir)
# Out:
# ...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %% [markdown]
# ## Predict

# %%
minimum_requirements = [
    "5+ years of Python software engineering experience",
    "Strong understanding of IT infrastructure",
    "Experience with AWS cloud services",
]

resume = """Muhammad Talha Riaz
Email: talhariaz9969@gmail.com
Software Engineer with 3 years of Python, Django, and data pipeline experience.
Built internal automation tools and collaborated with DevOps teams.
Familiar with Linux servers and networking fundamentals.
"""

result = matcher.predict(minimum_requirements=minimum_requirements, resume=resume)
result
# Out:
# {'scores': {'requirements': [{'criteria': '5+ years of Python software engineering experience',
#     'meets': False,
#     'probability': 0.2294},
#    {'criteria': 'Strong understanding of IT infrastructure',
#     'meets': False,
#     'probability': 0.1803},
#    {'criteria': 'Experience with AWS cloud services',
#     'meets': False,
#     'probability': 0.1446}]},
#  'personal_info': {'name': 'Muhammad Talha Riaz',
#   'email': 'talhariaz9969@gmail.com',
#   'phone': None,
#   'linkedin': None,
#   'github': None}}

# %% [markdown]
# ## JSON Output

# %%
import json

print(json.dumps({"input": {"minimum_requirements": minimum_requirements, "resume": resume}, "output": result}, indent=2))
# Out:
# {
#   "input": {
#     "minimum_requirements": [
#       "5+ years of Python software engineering experience",
#       "Strong understanding of IT infrastructure",
#       "Experience with AWS cloud services"
#     ],
#     "resume": "Muhammad Talha Riaz\nEmail: talhariaz9969@gmail.com\nSoftware Engineer with 3 years of Python, Django, and data pipeline experience.\nBuilt internal automation tools and collaborated with DevOps teams.\nFamiliar with Linux servers and networking fundamentals.\n"
#   },
#   "output": {
#     "scores": {
#       "requirements": [
#         {
#           "criteria": "5+ years of Python software engineering experience",
#           "meets": false,
#           "probability": 0.2294
#         },
#         {
#           "criteria": "Strong understanding of IT infrastructure",
#           "meets": false,
#           "probability": 0.1803
#         },
#         {
#           "criteria": "Experience with AWS cloud services",
#           "meets": false,
# ...
