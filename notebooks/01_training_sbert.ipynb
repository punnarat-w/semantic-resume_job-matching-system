# %% [markdown]
# # Training Notebook: Semetic BERT + Logistic Regression
#
# This notebook trains the requirement-level binary classifier. Each training row contains a resume, a list of minimum requirements, and one binary label per requirement.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

PROJECT_ROOT
# Out:
# PosixPath('/Users/punpunpmbp/Documents/Documents/THU_Project/DL/semantic-resume_job-matching-system')

# %% [markdown]
# ## Inspect Sample Data

# %%
import json
from pprint import pprint

sample_path = PROJECT_ROOT / "data" / "processed" / "resume_score_details.jsonl"
if not sample_path.exists():
    sample_path = PROJECT_ROOT / "data" / "raw" / "sample.jsonl"

with sample_path.open("r", encoding="utf-8") as f:
    first_record = json.loads(next(f))

pprint(first_record)
# Out:
# {'labels': [1, 1, 1],
#  'minimum_requirements': ['Proficiency in conducting and managing FAT/SAT',
#                           "Bachelor's degree in Electrical Engineering",
#                           '10+ years of experience in project management and '
#                           'electrical design'],
#  'resume': 'ABDULLAH JAWAID \n'
#            'Gulshan e Iqbal, block 2, Karachi, 75300 | +92 334 3664340 | '
#            'abdullahjawaid@hotmail.com  \n'
#            'Summary Statement \n'
#            '\uf0b7 Initiative-taking Electrical Engineer with 10+ years of '
#            'experience excelling in electrical design, project \n'
#            'management, and Installation, Testing & Commissioning. Proven '
#            'record in team engagement, \n'
#            'equipment procurement, and project execution. Effective '
#            'communicator with expertise in handling \n'
#            'contractors, vendors, and clients. Proficient in progress '
#            'reporting and adept at ensuring project success \n'
#            'through meticulous diligence and efficient procedures. \n'
#            'Project Based Experience  \n'
#            '\uf0b7 Testing & Pre-Commissioning Lead  | E-House for DS03 '
#            'Electrical Power Upgrade at CPS4  for \n'
#            'Rumaila Operating Organization (ROO) – Iraq | May-Jul 2024  \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Thoroughly conducted internal testing of ABB ZS1 6.6kV '
#            'Switchboard (16 panels), including \n'
#            'motor and transformer feeders, EATON 400V switchboard, Chloride DC '
#            'UPS 60A, F&G \n'
#            'system, and auxiliary systems. \n'
#            '\uf0b7 Successfully led the integrated Factory Acceptance Test '
#            '(iFAT) with the customer for the entire \n'
#            'E-house, receiving appreciation for its successful completion. \n'
#            ' \n'
#            '\uf0b7 Project Lead  | LV Switchboard & Soft Starter Panels for '
#            'AVINA Clean Hydrogen Inc. – USA | \n'
#            'Apr-Present 2024  \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Leading the sourcing and design validation of ABB ReliaGear '
#            'Switchboard and standalone \n'
#            'PSTX series soft starters. \n'
#            '\uf0b7 Ensuring technical compliance and meeting tight deadlines '
#            'by offering fast delivery products. \n'
#            ' \n'
#            '\uf0b7 Commissioning Lead  | E-house Commissioning Services at '
#            'Basrah Natural Gas Liquefaction Plant \n'
#            '(BNGL), Basrah Gas Company (BGC) – Iraq | Mar-Apr 2023 & Jan-Apr '
#            '2024  \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Managed multiple vendors and clients from technical, '
#            'commercial and administrative aspects to \n'
#            'execute Site Acceptance Tests, pre-commissioning, and '
#            'commissioning of 4 E-houses.  \n'
#            '\uf0b7 Provided technical support for first solo/load runs of the '
#            'medium and low voltage motors and \n'
#            'troubleshooting throughout the project execution. \n'
#            '\uf0b7 Enhanced my role by conducting mechanical inspections, '
#            'interlock checks, and making logic \n'
#            'modifications to the switchgear, all to accommodate customer '
#            'budget constraints. \n'
#            ' \n'
#            '\uf0b7 Installation Supervisor  | Casting of Cast Resin Sandwich '
#            'Bus ducts – 4000 A –  KM500 Gas \n'
#            'Treatment Plant (Pearl Petroleum) – Kurdistan Region of Iraq | Jan '
#            '2024  \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Effectively supervised the casting of Cast Resin Sandwich '
#            'Bus ducts rated at 4000 A.  \n'
#            '\uf0b7 Displayed my adaptability by taking on challenges and '
#            'self-training to meet and exceed \n'
#            'customer requirements. 2  \n'
#            '\uf0b7 Commissioning Lead  | ABB E-house Commissioning Services at '
#            'Basrah Natural Gas Liquefaction \n'
#            'Plant (BNGL), Basrah Gas Company (BGC) – Iraq  3 Nos. Substations '
#            '| May – Dec 2023  \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Managed multiple vendors and clients from technical, '
#            'commercial and administrative aspects to \n'
#            'execute Site Acceptance Tests, pre-commissioning, and '
#            'commissioning of 3 ABB E-houses.  \n'
#            '\uf0b7 Provided technical support for site modifications as per '
#            'customer requirements. \n'
#            ' \n'
#            '\uf0b7 Electrical Lead  | Frontier Works Organization 10,000 cubic '
#            'meter / day SWRO Plant, Karachi – \n'
#            'Karachi Nuclear Power Plant |  Apr 2019 – Jan 2023  \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Single handedly managed multiple vendors and clients from '
#            'technical, commercial, and \n'
#            'administrative aspects throughout the design, procurement, '
#            'installation, testing and \n'
#            'commissioning phases of the project. \n'
#            '\uf0b7 Eyed for details to follow stringent nuclear facility '
#            'requirements such as sourcing of scarcely \n'
#            'available Class 1E category power cables. \n'
#            '\uf0b7 Used my negotiation skills to close out the procurement '
#            'within budget and ensured deliveries \n'
#            'ahead of schedule. \n'
#            ' \n'
#            '\uf0b7 Electrical Engineer  | 8.2 MW 18V32 HFO Engine (used) with '
#            'Switchgear System Engineering \n'
#            'Review, Procurement, Installation & Commissioning – National '
#            'Refinery Limited (NRL), Karachi | \n'
#            '2017 – 2018.  \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Supported team in the design, procurement and installation '
#            'commissioning.  \n'
#            ' \n'
#            '\uf0b7 Electrical Engineer  | Implementation of Yokogawa DCS in '
#            'Lube Refinery – NRL | 2017 – 2018 \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Successfully devised conceptual circuit for MCC operation '
#            'from DCS, approved by Yokogawa \n'
#            'engineering team and implemented. \n'
#            '\uf0b7 Enhanced site grounding system to follow Yokogawa '
#            'requirement. \n'
#            ' \n'
#            '\uf0b7 Project Lead  | Electrical System Upgrade of 4 MW 12V32 HFO '
#            'Engine (Wartsila) – NRL | 2016 – \n'
#            '2018 \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Studied existing system and presented to Wartsila team to '
#            'integrate new system with old system. \n'
#            ' \n'
#            '\uf0b7 Electrical Engineer  | Replacement of 7.5 MW Steam Turbine, '
#            'Control System Upgrade, and \n'
#            'Overhauling of Alternator – NRL | 2015 – 2017.  \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Took charge of the project midway to address engineering '
#            'challenges related to synchronization, \n'
#            'load sharing, and integrating with the existing system. \n'
#            ' \n'
#            ' 3 \uf0b7 Electrical Engineer  | Revamp of Crude Distillation Unit '
#            '– NRL | 2015 – 2016  \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Reviewed FEED documents and ensured project compliance '
#            'according to the design. \n'
#            ' \n'
#            '\uf0b7 Trainee – Senior Management  | National Refinery Limited  '
#            '(NRL) | 2014 – 2015  \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Demonstrated active involvement in troubleshooting in '
#            'different process areas including power \n'
#            'generation. Was awarded with outstanding appraisal during this '
#            'period. \n'
#            ' \n'
#            '\uf0b7 Trainee Engineer  | Installation of Vertical Cement Mills - '
#            'Lucky Cement Limited  | 2014 \n'
#            '\uf0b7 Achievements:  \n'
#            '\uf0b7 Effectively worked on switchgear protection relay testing '
#            'and power cables testing. \n'
#            'Education  \n'
#            'Master of Engineering Management (Industrial Management)  | NED '
#            'university of engineering and \n'
#            'technology, Karachi, Pakistan | 2015 – 2016  \n'
#            'Bachelor of Engineering (Electrical)  | NED university of '
#            'engineering and technology, Karachi, Pakistan \n'
#            '| 2010 – 2013  \n'
#            'Skills & Abilities  \n'
#            'Certifications  \n'
#            '\uf0b7 Cast Resin Bus duct Installation and Maintenance | Virtual '
#            'Training by LINKK | Dec 2023 \n'
#            '\uf0b7 Professional Engineer (Electrical Engineer) | ANZSCO Skill '
#            'Level 1| Engineers Australia | Dec 2022 \n'
#            '\uf0b7 O&M of 3500 Vibration Monitoring & Protection | Bentley '
#            'Nevada | Lahore 2018 \n'
#            '\uf0b7 Centum VP R6 (Maintenance, Engineering & PRM) | Yokogawa | '
#            'Singapore 2017 \n'
#            '\uf0b7 Advanced Power System Protection (ETAP) | NED University | '
#            'Karachi 2013 \n'
#            'Expertise  \n'
#            ' \n'
#            '\uf0b7 Electrical Design Evaluation \n'
#            '(FEED) \uf0b7 Project Management \uf0b7 Contractors / Vendors \n'
#            'Managing \n'
#            '\uf0b7 Team Engagement \uf0b7 Equipment Procurement / \n'
#            'Sourcing \uf0b7 Communication Skills \n'
#            '\uf0b7 Installation, Testing & \n'
#            'Commissioning \uf0b7 Conducting FAT / SAT \uf0b7 Project Costing '
#            'and \n'
#            'budgeting \n'
#            '\uf0b7 Functional Safety \uf0b7 Preparation of Work \n'
#            'Instructions and Procedures \uf0b7 Progress Reporting during \n'
#            'all stages of Project 4  \n'
#            'Executed Tasks  \n'
#            '\uf0b7 Leading Electrical Systems E-house projects including '
#            'design of Single Line Diagram, design / \n'
#            'review / selection MV & LV panels, cable sizing and cable routing, '
#            'selection of transformers, \n'
#            'selection of UPS, Fire Alarm System, and earthling system. \n'
#            '\uf0b7 Managing Installation, Testing and Commissioning of '
#            'E-houses \n'
#            '\uf0b7 Planning project baselines \n'
#            '\uf0b7 Performing design reviews/evaluation including power system '
#            'studies & presenting it to client for \n'
#            'approval \n'
#            '\uf0b7 Conducting procurement of project material such as HV/LV '
#            'components (XLPE Cables, Switchgear, \n'
#            'Transformers, Power Factor & Reactors, Lighting System, Earthling '
#            '/Grounding) \n'
#            '\uf0b7 Managing multiple stakeholders including consultants, '
#            'joint-venture partners, national & international \n'
#            'vendors, and contractors to satisfy client’s requirements. \n'
#            '\uf0b7 Aligning across functions tasks \n'
#            '\uf0b7 Initiating and leading activity/job planning sessions. \n'
#            '\uf0b7 Conducting FAT/SAT and Supervising & assisting '
#            'Installation, Testing & Commissioning of \n'
#            'Electrical Equipment \n'
#            '\uf0b7 Managing all incoming & outgoing documentation \n'
#            '\uf0b7 Monitoring & Controlling project baselines and keeping '
#            'track of Project Status \n'
#            '\uf0b7 Conducting project closeout \n'
#            'Experience  \n'
#            '\uf0b7 Senior Design & Application Engineer | Intech Process '
#            'Automation, Pakistan \n'
#            '(https://www.intechww.com/ ) | Jan 2023 – Present  \n'
#            '\uf0b7 Senior Deputy Manager | Frontier Works Organization, '
#            'Pakistan ( https://www.fwo.com.pk/ ) | \n'
#            'Apr 2019 – Jan 2023 \n'
#            '\uf0b7 Project Engineer | National Refinery Limited (NRL), '
#            'Pakistan ( http://www.nrlpak.com/ ) | Oct 2014 \n'
#            '– Apr 2019  \n'
#            '\uf0b7 Trainee Engineer | Lucky Cement Limited, Pakistan ( '
#            'https://www.lucky-cement.com/ ) | Jun 2014 – \n'
#            'Oct 2014 \n'
#            ' ',
#  'source_valid_resume_and_jd': True}

# %% [markdown]
# ## Train Baseline
#
# Use the processed Hugging Face JSONL if available; otherwise this falls back to the tiny sample file.

# %%
from semantic_resume_matcher.embeddings.train_sbert_logreg import train_sbert_logreg
train_path = PROJECT_ROOT / "data" / "processed" / "resume_score_details.jsonl"
if not train_path.exists():
    train_path = PROJECT_ROOT / "data" / "raw" / "sample.jsonl"

output_dir = PROJECT_ROOT / "artifacts" / "sbert_logreg"
config_path = PROJECT_ROOT / "configs" / "sbert_logreg.yaml"

metrics = train_sbert_logreg(train_path=train_path, output_dir=output_dir, config_path=config_path)
metrics
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Batches:   0%|          | 0/60 [00:00<?, ?it/s]
# Batches:   0%|          | 0/60 [00:00<?, ?it/s]
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]
# {'accuracy': 0.7832167832167832,
#  'precision': 0.782051282051282,
#  'recall': 0.8133333333333334,
#  'f1': 0.7973856209150327,
#  'num_validation_examples': 429,
#  'num_failures': 93}

# %% [markdown]
# ## Inspect Validation Failures

# %%
import pandas as pd

failures_path = output_dir / "validation_failures.jsonl"
if failures_path.stat().st_size == 0:
    failures_df = pd.DataFrame(columns=["requirement", "label", "prediction", "probability", "resume_snippet"])
    failures_df
else:
    failures_df = pd.read_json(failures_path, lines=True)
    failures_df.assign(confidence=lambda df: (df["probability"] - 0.5).abs()).sort_values("confidence", ascending=False).head(20)

# %% [markdown]
# ## Saved Artifacts

# %%
sorted(path.name for path in output_dir.iterdir())
# Out:
# ['classifier.joblib',
#  'config.json',
#  'metrics.json',
#  'validation_failures.jsonl',
#  'validation_predictions.jsonl']

# %%
# sentence-transformers/all-MiniLM-L6-v2
# {'accuracy': 0.7505827505827506,
#  'precision': 0.7657657657657657,
#  'recall': 0.7555555555555555,
#  'f1': 0.7606263982102909,
#  'num_validation_examples': 429,
#  'num_failures': 107}

# sentence-transformers/all-mpnet-base-v2
# {'accuracy': 0.7832167832167832,
#  'precision': 0.782051282051282,
#  'recall': 0.8133333333333334,
#  'f1': 0.7973856209150327,
#  'num_validation_examples': 429,
#  'num_failures': 93}

# BAAI/bge-base-en-v1.5
# {'accuracy': 0.7505827505827506,
#  'precision': 0.7836538461538461,
#  'recall': 0.7244444444444444,
#  'f1': 0.7528868360277137,
#  'num_validation_examples': 429,
#  'num_failures': 107}

# intfloat/e5-base-v2
# {'accuracy': 0.7435897435897436,
#  'precision': 0.7467811158798283,
#  'recall': 0.7733333333333333,
#  'f1': 0.759825327510917,
#  'num_validation_examples': 429,
#  'num_failures': 110}
